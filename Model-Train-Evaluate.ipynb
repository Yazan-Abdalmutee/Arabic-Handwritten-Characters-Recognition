label_20.png
# /kaggle/input/arabic-data-set/train/train/id_11530_label_14.png
# /kaggle/input/arabic-data-set/train/train/id_796_label_16.png
# /kaggle/input/arabic-data-set/train/train/id_5143_label_27.png
# /kaggle/input/arabic-data-set/train/train/id_1539_label_25.png
# /kaggle/input/arabic-data-set/train/train/id_8504_label_27.png
# /kaggle/input/arabic-data-set/train/train/id_973_label_10.png
# /kaggle/input/arabic-data-set/train/train/id_9495_label_11.png
# /kaggle/input/arabic-data-set/train/train/id_10579_label_7.png
# /kaggle/input/arabic-data-set/train/train/id_11262_label_8.png
# /kaggle/input/arabic-data-set/train/train/id_1313_label_25.png
# /kaggle/input/arabic-data-set/train/train/id_3078_label_21.png
# /kaggle/input/arabic-data-set/train/train/id_11475_label_7.png
# /kaggle/input/arabic-data-set/train/train/id_3080_label_21.png
# /kaggle/input/arabic-data-set/train/train/id_6571_label_10.png
# /kaggle/input/arabic-data-set/train/train/id_7455_label_8.png
# /kaggle/input/arabic-data-set/train/train/id_6132_label_11.png
# /kaggle/input/arabic-data-set/train/train/id_6257_label_27.png
# /kaggle/input/arabic-data-set/train/train/id_6741_label_3.png
# /kaggle/input/arabic-data-set/train/train/id_1857_label_9.png
# /kaggle/input/arabic-data-set/train/train/id_4047_label_2.png
# /kaggle/input/arabic-data-set/train/train/id_4703_label_28.png
# /kaggle/input/arabic-data-set/train/train/id_10001_label_19.png
# /kaggle/input/arabic-data-set/train/train/id_6537_label_6.png
# /kaggle/input/arabic-data-set/train/train/id_1434_label_12.png
# /kaggle/input/arabic-data-set/train/train/id_5528_label_19.png
# /kaggle/input/arabic-data-set/train/train/id_13153_label_21.png
# /kaggle/input/arabic-data-set/train/train/id_4374_label_15.png
# /kaggle/input/arabic-data-set/train/train/id_7777_label_21.png
# /kaggle/input/arabic-data-set/train/train/id_10331_label_4.png
# /kaggle/input/arabic-data-set/train/train/id_615_label_21.png
# /kaggle/input/arabic-data-set/train/train/id_8096_label_4.png
# /kaggle/input/arabic-data-set/train/train/id_10989_label_2.png
# /kaggle/input/arabic-data-set/train/train/id_11228_label_4.png
# /kaggle/input/arabic-data-set/train/train/id_12050_label_23.png
# /kaggle/input/arabic-data-set/train/train/id_2608_label_18.png
# /kaggle/input/arabic-data-set/train/train/id_5135_label_26.png
# /kaggle/input/arabic-data-set/train/train/id_5803_label_26.png
# /kaggle/input/arabic-data-set/train/train/id_10728_label_25.png
# /kaggle/input/arabic-data-set/train/train/id_9353_label_22.png
# /kaggle/input/arabic-data-set/train/train/id_11852_label_26.png
# /kaggle/input/arabic-data-set/train/train/id_11165_label_24.png
# /kaggle/input/arabic-data-set/train/train/id_10825_label_10.png
# /kaggle/input/arabic-data-set/train/train/id_10421_label_15.png
# /kaggle/input/arabic-data-set/train/train/id_6747_label_4.png
# /kaggle/input/arabic-data-set/train/train/id_8476_label_24.png
# /kaggle/input/arabic-data-set/train/train/id_11185_label_27.png
# /kaggle/input/arabic-data-set/train/train/id_108_label_14.png
# /kaggle/input/arabic-data-set/train/train/id_10876_label_16.png
# /kaggle/input/arabic-data-set/train/train/id_8097_label_5.png
# /kaggle/input/arabic-data-set/train/train/id_9405_label_28.png
# /kaggle/input/arabic-data-set/train/train/id_4984_label_7.png
# /kaggle/input/arabic-data-set/train/train/id_1396_label_7.png
# /kaggle/input/arabic-data-set/train/train/id_12479_label_20.png
# /kaggle/input/arabic-data-set/train/train/id_4311_label_7.png
# /kaggle/input/arabic-data-set/train/train/id_629_label_23.png
# /kaggle/input/arabic-data-set/train/train/id_195_label_25.png
# /kaggle/input/arabic-data-set/train/train/id_7843_label_1.png
# /kaggle/input/arabic-data-set/train/train/id_1284_label_21.png
# /kaggle/input/arabic-data-set/train/train/id_11013_label_5.png
# /kaggle/input/arabic-data-set/train/train/id_7026_label_11.png
# /kaggle/input/arabic-data-set/train/train/id_12975_label_26.png
# /kaggle/input/arabic-data-set/train/train/id_2647_label_23.png
# /kaggle/input/arabic-data-set/train/train/id_11248_label_6.png
# /kaggle/input/arabic-data-set/train/train/id_405_label_23.png
# /kaggle/input/arabic-data-set/train/train/id_10635_label_14.png
# /kaggle/input/arabic-data-set/train/train/id_4475_label_28.png
# /kaggle/input/arabic-data-set/train/train/id_2355_label_15.png
# /kaggle/input/arabic-data-set/train/train/id_10792_label_5.png
# /kaggle/input/arabic-data-set/train/train/id_5392_label_2.png
# /kaggle/input/arabic-data-set/train/train/id_6328_label_7.png
# /kaggle/input/arabic-data-set/train/train/id_3540_label_23.png
# /kaggle/input/arabic-data-set/train/train/id_3640_label_7.png
# /kaggle/input/arabic-data-set/train/train/id_6708_label_27.png
# /kaggle/input/arabic-data-set/train/train/id_4755_label_7.png
# /kaggle/input/arabic-data-set/train/train/id_11231_label_4.png
# /kaggle/input/arabic-data-set/train/train/id_203_label_26.png
# /kaggle/input/arabic-data-set/train/train/id_1551_label_26.png
# /kaggle/input/arabic-data-set/train/train/id_11505_label_11.png
# /kaggle/input/arabic-data-set/train/train/id_11556_label_17.png
# /kaggle/input/arabic-data-set/train/train/id_4748_label_6.png
# /kaggle/input/arabic-data-set/train/train/id_3775_label_24.png
# /kaggle/input/arabic-data-set/train/train/id_7836_label_28.png
# /kaggle/input/arabic-data-set/train/train/id_7983_label_18.png
# /kaggle/input/arabic-data-set/train/train/id_4402_label_19.png
# /kaggle/input/arabic-data-set/train/train/id_5505_label_17.png
# /kaggle/input/arabic-data-set/train/train/id_7398_label_1.png

# %%
import os
import torch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
import torch.nn as nn
from torch.autograd import Variable
import torchvision
from torchvision import transforms, datasets
from torch.utils.data import DataLoader, TensorDataset
from torch import Tensor

# %%
train_path = '/kaggle/input/arabic-data-set/train/train/'
test_path = '/kaggle/input/arabic-data-set/test/test/'

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import os
from PIL import Image


class CustomImageDataset(Dataset):
    def __init__(self, data_dir, transform=None):
        self.data_dir = data_dir
        self.transform = transform

        # Store the filenames and labels
        self.image_filenames = []
        self.labels = []
        for filename in os.listdir(data_dir):
            if filename.endswith('.png'):
                label = int(filename.split('_')[-1].split('.')[0]) - 1
                self.image_filenames.append(filename)
                self.labels.append(label)

    def __len__(self):
        return len(self.image_filenames)

    def __getitem__(self, idx):
        img_name = self.image_filenames[idx]
        label = self.labels[idx]
        img_path = os.path.join(self.data_dir, img_name)
        img = Image.open(img_path).convert('L')  # Convert to grayscale

        if self.transform:
            img = self.transform(img)

        return img, label


# Define transformations
transform = transforms.Compose([
    transforms.ToTensor(),
])

# %%
import os
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image

class NoisyImageDataset(Dataset):
    def __init__(self, data_dir, transform=None):
        self.data_dir = data_dir
        self.transform = transform

        # Store the filenames and labels
        self.image_filenames = []
        self.labels = []
        for filename in os.listdir(data_dir):
            if filename.endswith(('.jpg', '.jpeg', '.png')):
                # Assuming the label is encoded in the filename before the extension
                label = int(filename.split('_')[-1].split('.')[0]) - 1
                self.image_filenames.append(filename)
                self.labels.append(label)

    def __len__(self):
        return len(self.image_filenames)

    def __getitem__(self, idx):
        img_name = self.image_filenames[idx]
        label = self.labels[idx]
        img_path = os.path.join(self.data_dir, img_name)
        img = Image.open(img_path)

        if self.transform:
            img = self.transform(img)

        return img, label

def add_gaussian_noise(img_tensor, mean=-0.1, std=0.2):
    noise = torch.randn_like(img_tensor) * std + mean
    return img_tensor + noise

# Define transformations
gaussian_noise_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert image to tensor first
    transforms.Lambda(lambda x: add_gaussian_noise(x)),
])

# %%
def label_to_letter(label):
    arabic_letters = ['Alef', 'Baa', 'Taa', 'Thaa', 'Jeem', '7aa', 'Khaa', 'Dal', 'Dhal', 'Raa', 'Zain', 'Seen', 'Sheen', 'Saad', 'Daad', 'Taa', 'Dhaa', 'Ain', 'Ghain', 'Faa', 'Qaf', 'Kaf', 'Lam', 'Meem', 'Noon', 'Haa', 'Waw', 'Yaa']
    return arabic_letters[label]
def plot_images(images, labels, predictions, title, n_cols=5):
    n_rows = int(np.ceil(len(images) / n_cols))
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 5 * n_rows))
    fig.suptitle(title, fontsize=16)

    for i, (image, label, prediction) in enumerate(zip(images, labels, predictions)):
        ax = axes[i // n_cols, i % n_cols]
        ax.imshow(np.transpose(image, (1, 2, 0)))  # Assuming images are in the format (channels, height, width)
        true_letter = label_to_letter(label)
        predicted_letter = label_to_letter(prediction)
        ax.set_title(f'True: {true_letter}\nPredicted: {predicted_letter}')
        ax.axis('off')

    # Remove empty subplots if needed
    for j in range(len(images), n_rows * n_cols):
        fig.delaxes(axes.flatten()[j])

    plt.show()

# %%
from torch.utils.data import Dataset, ConcatDataset
from torchvision.transforms import RandomApply, GaussianBlur, ToTensor

rotate_transform = transforms.Compose([
    transforms.RandomRotation(degrees=70),
    transforms.ToTensor(),
])

shift_transform = transforms.Compose([
    transforms.RandomAffine(degrees=0, translate=(0.15, 0.15), scale=(0.67, 1.47)),
    transforms.ToTensor(),
])



shear_transform = transforms.Compose([
    transforms.RandomAffine(degrees=0, shear=20 , fill = 1 ),
    transforms.ToTensor(),
])


blur_transform = transforms.Compose([
    RandomApply([GaussianBlur(kernel_size=3)], p=0.8),
    transforms.ToTensor(),
])

blur_dataset = CustomImageDataset(train_path, transform=blur_transform)


rotate_dataset = CustomImageDataset(train_path, transform=rotate_transform)

shift_dataset = CustomImageDataset(train_path, transform=shift_transform)

#zoom_dataset = CustomImageDataset(train_path, transform=zoom_transform)

noisy_dataset = NoisyImageDataset(train_path, transform=gaussian_noise_transform)

shear_dataset = CustomImageDataset(train_path, transform=shear_transform)

train_image_dataset = CustomImageDataset(train_path, transform=transform)

#train_image_dataset_augmented = ConcatDataset([rotate_dataset, shift_dataset, zoom_dataset,train_image_dataset,noisy_dataset])
train_image_dataset_augmented = ConcatDataset([rotate_dataset, shift_dataset, shear_dataset,train_image_dataset,noisy_dataset,blur_dataset])


test_dataset = CustomImageDataset(test_path, transform=transform)
test_loader = DataLoader(test_dataset, batch_size= 1, shuffle=False)

# %%
print(len(train_image_dataset))
print(len(rotate_dataset))
print(len(shift_dataset))
print(len(test_dataset))
print(len(noisy_dataset))
print(len(train_image_dataset_augmented))

# %%
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(9, 9))
cols, rows = 4, 4
for i in range(1, cols * rows + 1):
  sample_idx = torch.randint(len(train_image_dataset), size=(1,)).item()
  img, label = train_image_dataset[sample_idx]
  figure.add_subplot(rows, cols, i)
  plt.title("digit:" + str(label))
  plt.axis("off")
  plt.imshow(img.squeeze(), cmap="gray")
plt.show()

# %%
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(9, 9))
cols, rows = 4, 4
for i in range(1, cols * rows + 1):
  sample_idx = torch.randint(len(blur_dataset), size=(1,)).item()
  img, label = blur_dataset[sample_idx]
  figure.add_subplot(rows, cols, i)
  plt.title("digit:" + str(label))
  plt.axis("off")
  plt.imshow(img.squeeze(), cmap="gray")
plt.show()

# %%
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(9, 9))
cols, rows = 4, 4
for i in range(1, cols * rows + 1):
  sample_idx = torch.randint(len(rotate_dataset), size=(1,)).item()
  img, label = rotate_dataset[sample_idx]
  figure.add_subplot(rows, cols, i)
  plt.title("digit:" + str(label))
  plt.axis("off")
  plt.imshow(img.squeeze(), cmap="gray")
plt.show()

# %%
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(9, 9))
cols, rows = 4, 4
for i in range(1, cols * rows + 1):
  sample_idx = torch.randint(len(shift_dataset), size=(1,)).item()
  img, label = shift_dataset[sample_idx]
  figure.add_subplot(rows, cols, i)
  plt.title("digit:" + str(label))
  plt.axis("off")
  plt.imshow(img.squeeze(), cmap="gray")
plt.show()

# %%
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(9, 9))
cols, rows = 4, 4
for i in range(1, cols * rows + 1):
  sample_idx = torch.randint(len(noisy_dataset), size=(1,)).item()
  img, label = noisy_dataset[sample_idx]
  figure.add_subplot(rows, cols, i)
  plt.title("digit:" + str(label))
  plt.axis("off")
  plt.imshow(img.squeeze(), cmap="gray")
plt.show()

# %%
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(9, 9))
cols, rows = 4, 4
for i in range(1, cols * rows + 1):
  sample_idx = torch.randint(len(shear_dataset), size=(1,)).item()
  img, label = shear_dataset[sample_idx]
  figure.add_subplot(rows, cols, i)
  plt.title("digit:" + str(label))
  plt.axis("off")
  plt.imshow(img.squeeze(), cmap="gray")
plt.show()

# %% [markdown]
# # Task 1

# %%
loader = DataLoader(train_image_dataset, batch_size= 64, shuffle=True)

# %%
import torch.nn as nn
from torch import Tensor
class ConvolutionNNetwork(nn.Module):
    def __init__(self):
        super(ConvolutionNNetwork, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))
        self.layer2 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))
        self.layer3 = nn.Sequential(
            nn.Conv2d(64, 64, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))
        self.drop_out = nn.Dropout()
        self.fc1 = nn.Linear(1024, 1000)
        self.fc2 = nn.Linear(1000, 28)
        
    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = out.reshape(out.size(0), -1)
        out = self.drop_out(out)
        out = self.fc1(out)
        out = self.fc2(out)
        return out

# %%
import torch
import torch.nn as nn

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

num_epochs = 32
learning_rate = 0.001
total_step = len(loader)

model = ConvolutionNNetwork().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate,weight_decay=1e-5);
criterion = nn.CrossEntropyLoss();


train_loss_list = []
train_acc_list = []

test_loss_list = []
test_acc_list = []
current_patience = 0
patience=5
model.train()
for epoch in range(num_epochs):
    model.train()
    epoch_train_loss = 0.0
    epoch_train_correct = 0
    epoch_train_total = 0
    for i, data in enumerate(loader):
        images, labels = data
        images, labels = images.to(device), labels.to(device)  # Move data to GPU

        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)
        #loss_list.append(loss.item())
        epoch_train_loss += loss.item()


        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Track the accuracy
        total = labels.size(0)
        _, predicted = torch.max(outputs.data, 1)
        correct = (predicted == labels).sum().item()
        #acc_list.append(correct / total)

        epoch_train_correct += correct
        epoch_train_total += total

        if (i + 1) % 100 == 0:
            print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, Accuracy: {:.2f}%'
                  .format(epoch + 1, num_epochs, i + 1, total_step, loss.item(),
                          (correct / total) * 100))
    model.eval()
    epoch_test_loss = 0.0
    epoch_test_correct = 0
    epoch_test_total = 0
    with torch.no_grad():
        correct = 0
        total = 0
        for (images, labels) in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total = labels.size(0)
            correct = (predicted == labels).sum().item()
            epoch_test_loss += criterion(outputs, labels).item()
            epoch_test_correct += correct
            epoch_test_total += total

        
    avg_test_loss = epoch_test_loss / len(test_loader)
    avg_test_acc = epoch_test_correct / epoch_test_total

    avg_train_loss = epoch_train_loss / len(loader)
    avg_train_acc = epoch_train_correct / epoch_train_total

    if epoch > 0 and avg_test_loss < test_loss_list[-1]:
        current_patience = 0
    else:
        current_patience += 1
    if current_patience >= patience:
        print(f'Early stopping at epoch {epoch + 1}')
        break
    test_loss_list.append(avg_test_loss)
    test_acc_list.append(avg_test_acc)
    train_loss_list.append(avg_train_loss)
    train_acc_list.append(avg_train_acc)
            


    print('Epoch [{}/{}], Train Loss: {:.4f}, Train Accuracy: {:.2f}%,, test Loss: {:.4f}, test Accuracy: {:.2f}%'
      .format(epoch + 1, num_epochs, avg_train_loss, avg_train_acc * 100,avg_test_loss, avg_test_acc* 100))
print('\n--- Finished ---\n')
# Out:
# cuda
# Epoch [1/32], Step [100/210], Loss: 1.2625, Accuracy: 53.12%
# Epoch [1/32], Step [200/210], Loss: 0.8806, Accuracy: 65.62%
# Epoch [1/32], Train Loss: 1.5768, Train Accuracy: 49.97%,, test Loss: 0.7032, test Accuracy: 78.24%
# Epoch [2/32], Step [100/210], Loss: 0.5688, Accuracy: 75.00%
# Epoch [2/32], Step [200/210], Loss: 0.5562, Accuracy: 81.25%
# Epoch [2/32], Train Loss: 0.6975, Train Accuracy: 76.36%,, test Loss: 0.4818, test Accuracy: 84.08%
# Epoch [3/32], Step [100/210], Loss: 0.7342, Accuracy: 76.56%
# Epoch [3/32], Step [200/210], Loss: 0.6956, Accuracy: 75.00%
# Epoch [3/32], Train Loss: 0.4912, Train Accuracy: 83.44%,, test Loss: 0.3379, test Accuracy: 89.17%
# Epoch [4/32], Step [100/210], Loss: 0.4658, Accuracy: 81.25%
# Epoch [4/32], Step [200/210], Loss: 0.6589, Accuracy: 81.25%
# Epoch [4/32], Train Loss: 0.3985, Train Accuracy: 86.60%,, test Loss: 0.3000, test Accuracy: 90.86%
# Epoch [5/32], Step [100/210], Loss: 0.3444, Accuracy: 87.50%
# Epoch [5/32], Step [200/210], Loss: 0.3570, Accuracy: 87.50%
# Epoch [5/32], Train Loss: 0.3206, Train Accuracy: 89.18%,, test Loss: 0.2765, test Accuracy: 90.98%
# Epoch [6/32], Step [100/210], Loss: 0.2283, Accuracy: 93.75%
# Epoch [6/32], Step [200/210], Loss: 0.2938, Accuracy: 89.06%
# Epoch [6/32], Train Loss: 0.2782, Train Accuracy: 90.73%,, test Loss: 0.2437, test Accuracy: 92.35%
# Epoch [29/32], Step [200/210], Loss: 0.0082, Accuracy: 100.00%
# Epoch [29/32], Train Loss: 0.0776, Train Accuracy: 97.31%,, test Loss: 0.2169, test Accuracy: 94.58%
# Epoch [30/32], Step [100/210], Loss: 0.0253, Accuracy: 100.00%
# Epoch [30/32], Step [200/210], Loss: 0.0618, Accuracy: 96.88%
# Epoch [30/32], Train Loss: 0.0656, Train Accuracy: 97.89%,, test Loss: 0.1982, test Accuracy: 95.36%
# Epoch [31/32], Step [100/210], Loss: 0.0352, Accuracy: 98.44%
# Epoch [31/32], Step [200/210], Loss: 0.1106, Accuracy: 93.75%
# Epoch [31/32], Train Loss: 0.0598, Train Accuracy: 97.97%,, test Loss: 0.2245, test Accuracy: 95.33%
# Epoch [32/32], Step [100/210], Loss: 0.1185, Accuracy: 93.75%
# Epoch [32/32], Step [200/210], Loss: 0.0402, Accuracy: 100.00%
# Epoch [32/32], Train Loss: 0.0710, Train Accuracy: 97.69%,, test Loss: 0.2658, test Accuracy: 94.08%
#
# --- Finished ---

# %%
pip install numpy>=1.16.5,<1.23.0 --upgrade
# Out:
# /bin/bash: 1.23.0: No such file or directory
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, accuracy_score
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
# Plot training and testing accuracy
axes[0].plot(range(1, num_epochs + 1), train_acc_list, label='Training Accuracy', color='blue')
axes[0].plot(range(1, num_epochs + 1), test_acc_list, label='Testing Accuracy', color='red')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].set_title('Training and Testing Accuracy over Epochs')
axes[0].legend()

# Plot training and testing loss
axes[1].plot(range(1, num_epochs + 1), train_loss_list, label='Training Loss', color='blue')
axes[1].plot(range(1, num_epochs + 1), test_loss_list, label='Testing Loss', color='red')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].set_title('Training and Testing Loss over Epochs')
axes[1].legend()

# Adjust layout to prevent clipping of titles
plt.tight_layout()

# Show the plots
plt.show()
model.eval()

# Lists to store predictions and ground truth labels
all_predictions = []
all_labels = []

with torch.no_grad():
    for (images, labels) in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)

        # Collect predictions and ground truth labels
        all_predictions.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# Confusion Matrix
conf_matrix = confusion_matrix(all_labels, all_predictions)

# Precision, Recall, and F1 Score
precision = precision_score(all_labels, all_predictions, average='weighted')
recall = recall_score(all_labels, all_predictions, average='weighted')
f1 = f1_score(all_labels, all_predictions, average='weighted')

# Accuracy
accuracy = accuracy_score(all_labels, all_predictions)

# Print the results
#print('Confusion Matrix:\n', conf_matrix)
print('\nWeighted Precision: {:.4f}'.format(precision))
print('Weighted Recall: {:.4f}'.format(recall))
print('Weighted F1 Score: {:.4f}'.format(f1))
print('\nTest Accuracy of the model on the test set: {:.2f} %'.format(accuracy * 100))
# Out:
# Weighted Precision: 0.9455
# Weighted Recall: 0.9408
# Weighted F1 Score: 0.9410
#
# Test Accuracy of the model on the test set: 94.08 %

# %%
model.eval()

# Lists to store predictions, ground truth labels, and images
all_predictions = []
all_labels = []
all_images = []

with torch.no_grad():
    for (images, labels) in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)

        # Collect predictions, ground truth labels, and images
        all_predictions.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
        all_images.extend(images.cpu().numpy())

# Get 9 random indices
random_indices = np.random.choice(len(all_images), 20, replace=False)

# Select images, labels, and predictions for the random indices
selected_images = [all_images[i] for i in random_indices]
selected_labels = [all_labels[i] for i in random_indices]
selected_predictions = [all_predictions[i] for i in random_indices]

# Plot the selected images
plot_images(selected_images, selected_labels, selected_predictions, title='Randomly Selected Predictions')

# %% [markdown]
# # Task 2

# %%
loader = DataLoader(train_image_dataset_augmented, batch_size= 64, shuffle=True)
test_dataset = CustomImageDataset(test_path, transform=transform)
test_loader = DataLoader(test_dataset, batch_size= 1, shuffle=False)

# %%
import torch
import torch.nn as nn
loader = DataLoader(train_image_dataset_augmented, batch_size= 128, shuffle=True)
test_dataset = CustomImageDataset(test_path, transform=transform)
test_loader = DataLoader(test_dataset, batch_size= 1, shuffle=False)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

num_epochs = 40
learning_rate = 0.001
total_step = len(loader)

model = ConvolutionNNetwork().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate);

criterion = nn.CrossEntropyLoss();

current_patience = 0 
patience = 5 




train_loss_list = []
train_acc_list = []

test_loss_list = []
test_acc_list = []

model.train()
for epoch in range(num_epochs):
    model.train()
    epoch_train_loss = 0.0
    epoch_train_correct = 0
    epoch_train_total = 0
    for i, data in enumerate(loader):
        images, labels = data
        images, labels = images.to(device), labels.to(device)  # Move data to GPU

        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)
        #loss_list.append(loss.item())
        epoch_train_loss += loss.item()


        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Track the accuracy
        total = labels.size(0)
        _, predicted = torch.max(outputs.data, 1)
        correct = (predicted == labels).sum().item()
        #acc_list.append(correct / total)

        epoch_train_correct += correct
        epoch_train_total += total

        if (i + 1) % 300 == 0:
            print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, Accuracy: {:.2f}%'
                  .format(epoch + 1, num_epochs, i + 1, total_step, loss.item(),
                          (correct / total) * 100))
    model.eval()
    epoch_test_loss = 0.0
    epoch_test_correct = 0
    epoch_test_total = 0
    with torch.no_grad():
        correct = 0
        total = 0
        for (images, labels) in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total = labels.size(0)
            correct = (predicted == labels).sum().item()
            
            loss = criterion(outputs, labels)
            epoch_test_loss += loss.item()
            epoch_test_correct += correct
            epoch_test_total += total

    avg_test_loss = epoch_test_loss / len(test_loader)
    avg_test_acc = epoch_test_correct / epoch_test_total

    avg_train_loss = epoch_train_loss / len(loader)
    avg_train_acc = epoch_train_correct / epoch_train_total

    if epoch > 0 and avg_test_loss < test_loss_list[-1]:
        current_patience = 0
    else:
        current_patience += 1

    if current_patience >= patience:
        print(f'Early stopping at epoch {epoch + 1}')
        break
    test_loss_list.append(avg_test_loss)
    test_acc_list.append(avg_test_acc)
    train_loss_list.append(avg_train_loss)
    train_acc_list.append(avg_train_acc)


    print('Epoch [{}/{}], Train Loss: {:.4f}, Train Accuracy: {:.2f}%,, test Loss: {:.4f}, test Accuracy: {:.2f}%'
      .format(epoch + 1, num_epochs, avg_train_loss, avg_train_acc * 100,avg_test_loss, avg_test_acc* 100))
print('\n--- Finished ---\n')
# Out:
# cuda
# Epoch [1/40], Step [400/630], Loss: 1.0262, Accuracy: 71.88%
# Epoch [1/40], Train Loss: 1.2371, Train Accuracy: 62.51%,, test Loss: 0.3461, test Accuracy: 90.42%
# Epoch [2/40], Step [400/630], Loss: 0.5611, Accuracy: 82.03%
# Epoch [2/40], Train Loss: 0.6610, Train Accuracy: 79.39%,, test Loss: 0.2157, test Accuracy: 93.60%
# Epoch [3/40], Step [400/630], Loss: 0.4843, Accuracy: 82.03%
# Epoch [3/40], Train Loss: 0.5202, Train Accuracy: 83.64%,, test Loss: 0.1685, test Accuracy: 95.15%
# Epoch [4/40], Step [400/630], Loss: 0.4983, Accuracy: 85.94%
# Epoch [4/40], Train Loss: 0.4512, Train Accuracy: 85.84%,, test Loss: 0.1518, test Accuracy: 95.30%
# Epoch [36/40], Step [400/630], Loss: 0.2709, Accuracy: 92.19%
# Epoch [36/40], Train Loss: 0.2152, Train Accuracy: 93.27%,, test Loss: 0.1316, test Accuracy: 96.52%
# Epoch [37/40], Step [400/630], Loss: 0.1348, Accuracy: 96.09%
# Epoch [37/40], Train Loss: 0.2138, Train Accuracy: 93.31%,, test Loss: 0.1397, test Accuracy: 96.22%
# Epoch [38/40], Step [400/630], Loss: 0.2848, Accuracy: 92.97%
# Epoch [38/40], Train Loss: 0.2117, Train Accuracy: 93.27%,, test Loss: 0.1295, test Accuracy: 96.67%
# Epoch [39/40], Step [400/630], Loss: 0.2802, Accuracy: 92.19%
# Epoch [39/40], Train Loss: 0.2124, Train Accuracy: 93.47%,, test Loss: 0.1275, test Accuracy: 96.82%
# Epoch [40/40], Step [400/630], Loss: 0.2230, Accuracy: 91.41%
# Epoch [40/40], Train Loss: 0.2094, Train Accuracy: 93.39%,, test Loss: 0.1367, test Accuracy: 96.31%
#
# --- Finished ---

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, accuracy_score
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
# Plot training and testing accuracy
axes[0].plot(range(1, num_epochs + 1), train_acc_list, label='Training Accuracy', color='blue')
axes[0].plot(range(1, num_epochs + 1), test_acc_list, label='Testing Accuracy', color='red')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].set_title('Training and Testing Accuracy over Epochs')
axes[0].legend()

# Plot training and testing loss
axes[1].plot(range(1, num_epochs + 1), train_loss_list, label='Training Loss', color='blue')
axes[1].plot(range(1, num_epochs + 1), test_loss_list, label='Testing Loss', color='red')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].set_title('Training and Testing Loss over Epochs')
axes[1].legend()

# Adjust layout to prevent clipping of titles
plt.tight_layout()

# Show the plots
plt.show()
model.eval()

# Lists to store predictions and ground truth labels
all_predictions = []
all_labels = []

with torch.no_grad():
    for (images, labels) in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)

        # Collect predictions and ground truth labels
        all_predictions.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# Confusion Matrix
conf_matrix = confusion_matrix(all_labels, all_predictions)

# Precision, Recall, and F1 Score
precision = precision_score(all_labels, all_predictions, average='weighted')
recall = recall_score(all_labels, all_predictions, average='weighted')
f1 = f1_score(all_labels, all_predictions, average='weighted')

# Accuracy
accuracy = accuracy_score(all_labels, all_predictions)

# Print the results
#print('Confusion Matrix:\n', conf_matrix)
print('\nWeighted Precision: {:.4f}'.format(precision))
print('Weighted Recall: {:.4f}'.format(recall))
print('Weighted F1 Score: {:.4f}'.format(f1))
print('\nTest Accuracy of the model on the test set: {:.2f} %'.format(accuracy * 100))
# Out:
# Weighted Precision: 0.9640
# Weighted Recall: 0.9631
# Weighted F1 Score: 0.9631
#
# Test Accuracy of the model on the test set: 96.31 %

# %%
model.eval()

# Lists to store predictions, ground truth labels, and images
all_predictions = []
all_labels = []
all_images = []

with torch.no_grad():
    for (images, labels) in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)

        # Collect predictions, ground truth labels, and images
        all_predictions.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
        all_images.extend(images.cpu().numpy())

# Get 9 random indices
random_indices = np.random.choice(len(all_images), 20, replace=False)

# Select images, labels, and predictions for the random indices
selected_images = [all_images[i] for i in random_indices]
selected_labels = [all_labels[i] for i in random_indices]
selected_predictions = [all_predictions[i] for i in random_indices]

# Plot the selected images
plot_images(selected_images, selected_labels, selected_predictions, title='Randomly Selected Predictions')
